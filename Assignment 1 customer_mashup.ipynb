# %%
#import the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sms
import bokeh as bk
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
customer_mashup = pd.read_csv('Customer_Mashup.csv')

# %%
customer_mashup
# Out:
#        ContractId Date_Of_Activity  Sum_Paid_To_Date  TokenIssued  \
# 0         1287671   7/20/2017 0:00             100.0            5
# 1         1287671   7/21/2017 0:00             100.0            5
# 2         1287671   7/22/2017 0:00             100.0            5
# 3         1287671   7/23/2017 0:00             100.0            5
# 4         1287671   7/24/2017 0:00             100.0            5
# ...           ...              ...               ...          ...
# 91611     1521082  12/16/2018 0:00             300.0           43
# 91612     1521082  12/17/2018 0:00             300.0           43
# 91613     1521082  12/18/2018 0:00             300.0           43
# 91614     1521082  12/19/2018 0:00             300.0           43
# 91615     1521082  12/20/2018 0:00             300.0           43
#
#       Credits_End_Date ContractStatus  AccountNumber  CustomerId  \
# 0       7/25/2017 0:00         ACTIVE      754517675      137046
# ...

# %%
doa = customer_mashup['Date_Of_Activity']

# %%
doa
# Out:
# 0         7/20/2017 0:00
# 1         7/21/2017 0:00
# 2         7/22/2017 0:00
# 3         7/23/2017 0:00
# 4         7/24/2017 0:00
#               ...
# 91611    12/16/2018 0:00
# 91612    12/17/2018 0:00
# 91613    12/18/2018 0:00
# 91614    12/19/2018 0:00
# 91615    12/20/2018 0:00
# Name: Date_Of_Activity, Length: 91616, dtype: object

# %%
sptd = customer_mashup["Sum_Paid_To_Date"]

# %%
sptd
# Out:
# 0        100.0
# 1        100.0
# 2        100.0
# 3        100.0
# 4        100.0
#          ...
# 91611    300.0
# 91612    300.0
# 91613    300.0
# 91614    300.0
# 91615    300.0
# Name: Sum_Paid_To_Date, Length: 91616, dtype: float64

# %%
plt.plot(doa, sptd)
plt.legend(['doa', 'sptd'])
plt.xlabel('doa')
plt.ylabel('sptd')
plt.show()

# %%
customer_mashup.describe()
# Out:
#          ContractId  Sum_Paid_To_Date   TokenIssued  AccountNumber  \
# count  9.161600e+04      91616.000000  91616.000000   9.161600e+04
# mean   1.322289e+06        553.970407    160.863779   4.837653e+08
# std    1.468088e+04        378.021677    116.796033   3.096801e+08
# min    1.287671e+06         20.000000      0.000000   4.130000e+04
# 25%    1.318708e+06        259.000000     65.000000   1.909681e+08
# 50%    1.322332e+06        460.000000    137.000000   4.922250e+08
# 75%    1.324283e+06        800.000000    240.000000   7.715033e+08
# max    1.521082e+06       2449.630000    615.000000   9.962787e+08
#
#           CustomerId   dailyAmount  Deposit_Amount  Product_Price  \
# count   91616.000000  91616.000000    91616.000000   91616.000000
# mean   169292.798594      2.617207      138.567063    1933.966338
# std     11821.972677      0.739186       66.967095    1128.937289
# min    137046.000000      2.000000       20.000000     900.000000
# ...

# %%
ob = customer_mashup["Outstanding_Balance"]

# %%
ob
# Out:
# 0        1000.0
# 1        1000.0
# 2        1000.0
# 3        1000.0
# 4        1000.0
#           ...
# 91611    3400.0
# 91612    3400.0
# 91613    3400.0
# 91614    3400.0
# 91615    3400.0
# Name: Outstanding_Balance, Length: 91616, dtype: float64

# %%
dep_amt = customer_mashup['Deposit_Amount']

# %%
dep_amt
# Out:
# 0        100
# 1        100
# 2        100
# 3        100
# 4        100
#         ...
# 91611    200
# 91612    200
# 91613    200
# 91614    200
# 91615    200
# Name: Deposit_Amount, Length: 91616, dtype: int64

# %%
plt.plot(dep_amt, ob)
plt.legend(['dep_amt','ob'])
plt.xlabel('dep_amt')
plt.ylabel('ob')
plt.show()
